# %%
# %load_ext autoreload
from bs4 import BeautifulSoup
from numpy import *
import matplotlib.pyplot as plt 
import pylab as pl
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
soup = BeautifulSoup(open("studenci_uw_imiona.html"))
people = soup.findAll("div", { "class" : "fsl fwb fcb" })
S = []
for person in people:
    S.append((person.string).split(' ', 1)[0])
imiona = dict((x, S.count(x)) for x in S if S.count(x) > 7)

# %%
d = [(key, value) for key, value in imiona.iteritems()]
d.sort()
print(d)

plt.bar(range(len(d)), imiona.values(), align='center', alpha=0.9)
plt.xticks(range(len(d)), imiona.keys(), rotation='-45')
# Out:
# [(u'Adam', 29), (u'Agata', 11), (u'Agnieszka', 31), (u'Aleksander', 15), (u'Aleksandra', 21), (u'Andrzej', 12), (u'Ania', 15), (u'Anna', 22), (u'Artur', 10), (u'Bartek', 16), (u'Bartosz', 14), (u'Bart\u0142omiej', 8), (u'Damian', 13), (u'Daniel', 10), (u'Dominik', 14), (u'Dominika', 11), (u'Ewa', 12), (u'Filip', 13), (u'Grzegorz', 21), (u'Hubert', 9), (u'Jacek', 10), (u'Jakub', 45), (u'Jan', 17), (u'Joanna', 18), (u'Julia', 11), (u'Kacper', 10), (u'Kamil', 30), (u'Karol', 18), (u'Karolina', 19), (u'Kasia', 21), (u'Katarzyna', 29), (u'Konrad', 16), (u'Krzysiek', 11), (u'Krzysztof', 37), (u'Kuba', 20), (u'Maciej', 28), (u'Maciek', 11), (u'Magda', 15), (u'Magdalena', 18), (u'Marcin', 44), (u'Marek', 13), (u'Marta', 21), (u'Martyna', 10), (u'Mateusz', 58), (u'Micha\u0142', 98), (u'Miko\u0142aj', 12), (u'Monika', 15), (u'Natalia', 15), (u'Ola', 12), (u'Olga', 9), (u'Paulina', 11), (u'Pawe\u0142', 45), (u'Piotr', 52), (u'Przemek', 11), (u'Rafa\u0142', 23), (u'Szymon', 15), (u'Tomasz', 25), (u'Tomek', 19), (u'Wojciech', 14), (u'Wojtek', 13), (u'\u0141ukasz', 34)]
# ([<matplotlib.axis.XTick at 0x7f836e8a83d0>,
#   <matplotlib.axis.XTick at 0x7f836e8b3290>,
#   <matplotlib.axis.XTick at 0x7f83720fd210>,
#   <matplotlib.axis.XTick at 0x7f836e5c9f90>,
#   <matplotlib.axis.XTick at 0x7f836e5ce4d0>,
#   <matplotlib.axis.XTick at 0x7f836e5cea50>,
#   <matplotlib.axis.XTick at 0x7f836e5dc4d0>,
#   <matplotlib.axis.XTick at 0x7f836e47a790>,
#   <matplotlib.axis.XTick at 0x7f836e47af10>,
#   <matplotlib.axis.XTick at 0x7f836e4046d0>,
#   <matplotlib.axis.XTick at 0x7f836e404e50>,
#   <matplotlib.axis.XTick at 0x7f836e40d610>,
#   <matplotlib.axis.XTick at 0x7f836e40dd90>,
#   <matplotlib.axis.XTick at 0x7f836e418550>,
#   <matplotlib.axis.XTick at 0x7f836e418cd0>,
#   <matplotlib.axis.XTick at 0x7f836e420490>,
#   <matplotlib.axis.XTick at 0x7f836e420c10>,
#   <matplotlib.axis.XTick at 0x7f836e42a3d0>,
#   <matplotlib.axis.XTick at 0x7f836e42ab50>,
#   <matplotlib.axis.XTick at 0x7f836e433310>,
#   <matplotlib.axis.XTick at 0x7f836e433a90>,
#   <matplotlib.axis.XTick at 0x7f836e43d250>,
#   <matplotlib.axis.XTick at 0x7f836e43d9d0>,
#   <matplotlib.axis.XTick at 0x7f836e3c6190>,
#   <matplotlib.axis.XTick at 0x7f836e3c6910>,
#   <matplotlib.axis.XTick at 0x7f836e3d00d0>,
#   <matplotlib.axis.XTick at 0x7f836e3d0850>,
#   <matplotlib.axis.XTick at 0x7f836e3d0fd0>,
#   <matplotlib.axis.XTick at 0x7f836e3da790>,
#   <matplotlib.axis.XTick at 0x7f836e3daf10>,
#   <matplotlib.axis.XTick at 0x7f836e3e36d0>,
#   <matplotlib.axis.XTick at 0x7f836e3e3e50>,
#   <matplotlib.axis.XTick at 0x7f836e3ed610>,
#   <matplotlib.axis.XTick at 0x7f836e3edd90>,
#   <matplotlib.axis.XTick at 0x7f836e3f7550>,
#   <matplotlib.axis.XTick at 0x7f836e3f7cd0>,
#   <matplotlib.axis.XTick at 0x7f836e401490>,
#   <matplotlib.axis.XTick at 0x7f836e401c10>,
#   <matplotlib.axis.XTick at 0x7f836e38b3d0>,
#   <matplotlib.axis.XTick at 0x7f836e38bb50>,
#   <matplotlib.axis.XTick at 0x7f836e394310>,
#   <matplotlib.axis.XTick at 0x7f836e394a90>,
#   <matplotlib.axis.XTick at 0x7f836e39e250>,
#   <matplotlib.axis.XTick at 0x7f836e39e9d0>,
#   <matplotlib.axis.XTick at 0x7f836e3a9190>,
#   <matplotlib.axis.XTick at 0x7f836e3a9910>,
#   <matplotlib.axis.XTick at 0x7f836e3b10d0>,
#   <matplotlib.axis.XTick at 0x7f836e3b1850>,
#   <matplotlib.axis.XTick at 0x7f836e3b1fd0>,
#   <matplotlib.axis.XTick at 0x7f836e3bb790>,
#   <matplotlib.axis.XTick at 0x7f836e3bbf10>,
#   <matplotlib.axis.XTick at 0x7f836e3456d0>,
#   <matplotlib.axis.XTick at 0x7f836e345e50>,
#   <matplotlib.axis.XTick at 0x7f836e34e610>,
#   <matplotlib.axis.XTick at 0x7f836e34ed90>,
#   <matplotlib.axis.XTick at 0x7f836e359550>,
#   <matplotlib.axis.XTick at 0x7f836e359cd0>,
#   <matplotlib.axis.XTick at 0x7f836e361490>,
#   <matplotlib.axis.XTick at 0x7f836e361c10>,
#   <matplotlib.axis.XTick at 0x7f836e36c3d0>,
#   <matplotlib.axis.XTick at 0x7f836e36cb50>],
#  <a list of 61 Text xticklabel objects>)

# %%
import matplotlib
matplotlib.style.use('ggplot')
df = pd.DataFrame(imiona.items(), columns=['Imie', 'Czestotliwosc'])
df = df.sort(columns='Czestotliwosc', ascending=False)
print(df)
df.plot(kind='barh', x=df.Imie, position=0.7, sort_columns=True)
# Out:
#           Imie  Czestotliwosc
# 48      Michał             98
# 40     Mateusz             58
# 60       Piotr             52
# 28       Paweł             45
# 0        Jakub             45
# 4       Marcin             44
# 24   Krzysztof             37
# 17      Łukasz             34
# 3    Agnieszka             31
# 47       Kamil             30
# 41        Adam             29
# 58   Katarzyna             29
# 36      Maciej             28
# 46      Tomasz             25
# 45       Rafał             23
# 12        Anna             22
# 59    Grzegorz             21
# 1   Aleksandra             21
# 51       Kasia             21
# 43       Marta             21
# 29        Kuba             20
# 15       Tomek             19
# 16    Karolina             19
# 27   Magdalena             18
# 31       Karol             18
# 52      Joanna             18
# 7          Jan             17
# 50      Konrad             16
# 57      Bartek             16
# 26      Monika             15
# ..         ...            ...
# 18  Aleksander             15
# 13      Szymon             15
# 10       Magda             15
# 33     Natalia             15
# 25    Wojciech             14
# 37     Bartosz             14
# 38     Dominik             14
# 32      Damian             13
# 6        Filip             13
# 14       Marek             13
# 11      Wojtek             13
# 5          Ewa             12
# 21         Ola             12
# 22     Mikołaj             12
# 30     Andrzej             12
# 35      Maciek             11
# 49       Julia             11
# 23    Krzysiek             11
# 39     Paulina             11
# 44       Agata             11
# 8      Przemek             11
# 42    Dominika             11
# 2      Martyna             10
# 54       Artur             10
# 56      Kacper             10
# 20      Daniel             10
# 9        Jacek             10
# 34        Olga              9
# 53      Hubert              9
# 55  Bartłomiej              8
#
# [61 rows x 2 columns]

# %%
import re
def getFriends(link):
    wojtek = BeautifulSoup(link.read())
    print(wojtek.prettify())
    friends = wojtek.findAll('a', {'class' :'uiLinkSubtle'}, href=re.compile('friends$'))
    if len(friends) > 0:
        friends=friends[0].string
        name = wojtek.findAll('span', {'id' :'fb-timeline-cover-name'})[0].string.split(' ', 1)[0]
    else:
        friends=""
        name=""
    print(name + " " + friends)
    return name, friends

# %%
import urllib2
url="https://www.facebook.com/psorek139"
page=urllib2.urlopen(url)
print(getFriends(page))
# Out:
# <!DOCTYPE html>
# <html class="no_js" id="facebook" lang="pl">
#  <head>
#   <meta charset="utf-8"/>
#   <script>
#    function envFlush(a){function b(c){for(var d in a)c[d]=a[d];}if(window.requireLazy){window.requireLazy(['Env'],b);}else{window.Env=window.Env||{};b(window.Env);}}envFlush({"ajaxpipe_token":"AXgpo_E8BDS6Qq2R","lhsh":"lAQHOUmig"});
#   </script>
#   <script>
#    CavalryLogger=false;
#   </script>
#   <noscript>
#    <meta content="0; URL=/psorek139?_fb_noscript=1" http-equiv="refresh"/>
#   </noscript>
#   <meta content="default" id="meta_referrer" name="referrer"/>
#   <title id="pageTitle">
#    Facebook
#   </title>
#   <link href="https://static.xx.fbcdn.net/rsrc.php/yV/r/hzMapiNYYpW.ico" rel="shortcut icon"/>
#   <link crossorigin="anonymous" data-bootloader-hash="Ltgte" href="https://static.xx.fbcdn.net/rsrc.php/v2/y7/r/pL6hNn88iEN.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" data-bootloader-hash="8Pnum" data-permanent="1" href="https://static.xx.fbcdn.net/rsrc.php/v2/yp/r/5f0DdiZ1C-X.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" data-bootloader-hash="2smJx" data-permanent="1" href="https://static.xx.fbcdn.net/rsrc.php/v2/yh/r/af6WwT5PYYN.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" data-bootloader-hash="zIx9O" data-permanent="1" href="https://static.xx.fbcdn.net/rsrc.php/v2/yq/r/Zuq0G_YDUSO.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" data-bootloader-hash="0Qu7U" data-permanent="1" href="https://static.xx.fbcdn.net/rsrc.php/v2/y-/r/jI7crWaxDPI.css" rel="stylesheet" type="text/css"/>
#   <script crossorigin="anonymous" data-bootloader-hash="8HR1A" src="https://static.xx.fbcdn.net/rsrc.php/v2/yQ/r/bblGxbgH4YL.js">
#   </script>
#   <script>
#    require("TimeSlice").guard(function() {(require("ServerJSDefine")).handleDefines([["URLFragmentPreludeConfig",[],{"incorporateQuicklingFragment":true,"hashtagRedirect":true},137],["BootloaderConfig",[],{"maxJsRetries":0,"isMobile":false},329],["CSSLoaderConfig",[],{"timeout":5000,"modulePrefix":"BLCSS:"},619],["LinkshimHandlerConfig",[],{"supports_meta_referrer":false,"default_meta_referrer_policy":"default","render_verification_rate":1000},27],["TrackingConfig",[],{"domain":"https:\/\/pixel.facebook.com"},325],["CurrentCommunityInitialData",[],{},490],["CurrentUserInitialData",[],{"USER_ID":"0","ACCOUNT_ID":"0"},270],["DTSGInitialData",[],{},258],["ISB",[],{},330],["LSD",[],{"token":"AVpfMwnq"},323],["SiteData",[],{"revision":2028872,"tier":"","push_phase":"V3","pkg_cohort":"EXP1:DEFAULT","spdy_enabled":false,"haste_site":"www","vip":"31.13.92.36"},317],["UserAgentData",[],{"browserArchitecture":"32","browserFullVersion":null,"browserMinorVersion":null,"browserName":"Unknown","browserVersion":null,"deviceName":"Unknown","engineName":"Unknown","engineVersion":null,"platformArchitecture":"32","platformName":"Unknown","platformVersion":null,"platformFullVersion":null},527],["BanzaiConfig",[],{"EXPIRY":86400000,"MAX_SIZE":10000,"MAX_WAIT":150000,"RESTORE_WAIT":150000,"blacklist":["time_spent"],"gks":{"boosted_component":true,"boosted_pagelikes":true,"boosted_posts":true,"boosted_website":true,"jslogger":true,"mercury_send_error_logging":true,"miny_compression":true,"pages_client_logging":true,"platform_oauth_client_events":true,"time_spent_bit_array":true,"useraction":true,"videos":true,"visibility_tracking":true,"vitals":true,"allow_userid_mismatch":true,"graphexplorer":true}},7],["CoreWarningGK",[],{"forceWarning":false},725],["FbtNumber",["IntlPolishNumberType"],{"impl":{"__m":"IntlPolishNumberType"}},605],["FbtResultGK",[],{"shouldReturnFbtResult":false,"inlineMode":false},876],["IntlViewerContext",[],{"GENDER":50331648},772],["FbtLogger",[],{"logger":null},288],["FbtQTOverrides",[],{"overrides":{}},551],["ReactGK",[],{"useCreateElement":false},998],["AsyncRequestConfig",[],{"pkgCohort":"EXP1:DEFAULT","PKG_COHORT_KEY":"__pc","retryOnNetworkError":"1"},328],["ZeroCategoryHeader",[],{},1127],["BigPipeExperiments",[],{"prefetch":"none","download_js":"blocked_by_dom_ready","link_images_to_pagelets":false},907],["ErrorSignalConfig",[],{"uri":"https:\/\/error.facebook.com\/common\/scribe_endpoint.php"},319],["DisplaySnowliftProfilePhotoNux",[],{"display":false},817],["SessionNameConfig",[],{"seed":"0L1j"},757],["PageTransitionsConfig",[],{"reloadOnBootloadError":false},1067],["PhotoSnowliftActionsGating",[],{"ALLOW_MAKE_COVER_PHOTO_BUTTON":false,"ALLOW_MAKE_PROFILE_PICTURE_BUTTON":false},887],["InitialServerTime",[],{"serverTime":1446770593000},204],["VideoPlayerAbortLoadingExperiment",[],{"canAbort":false,"withoutLoad":true},824]]);new (require("ServerJS"))().handle({"require":[["TimeSlice"],["markJSEnabled"],["lowerDomain"],["URLFragmentPrelude"],["Primer"],["BigPipe"],["Bootloader"]]});}, "ServerJS define", {"root":true})();
#   </script>
#  </head>
#  <body class="fbx UIPage_LoggedOut _2gsg _xw8 _5p3y x1 body_textalign Locale_pl_PL" dir="ltr">
#   <div class="_li">
#    <div data-referrer="pagelet_bluebar" id="pagelet_bluebar">
#     <div>
#      <div class="_21mm _2gsf" id="blueBarDOMInspector">
#       <div class="_4f7n _hdd _xxp" id="blueBarNAXAnchor">
#        <div>
#         <div class="loggedout_menubar_container">
#          <div class="clearfix loggedout_menubar">
#           <div class="lfloat _ohe">
#            <h1>
#             <a href="https://www.facebook.com/" title="Przejdź na stronę główną Facebooka">
#              <i class="fb_logo img sp_7XMX65Pq0E7 sx_ccd1d2">
#               <u>
#                Logo Facebooka
#               </u>
#              </i>
#             </a>
#            </h1>
#           </div>
#           <div class="menu_login_container rfloat _ohf">
#            <form action="https://www.facebook.com/login.php?login_attempt=1&amp;lwv=110" id="login_form" method="post" novalidate="1" onsubmit="return window.Event &amp;&amp; Event.__inlineSubmit &amp;&amp; Event.__inlineSubmit(this,event)">
#             <input autocomplete="off" name="lsd" type="hidden" value="AVpfMwnq"/>
#             <table cellspacing="0" role="presentation">
#              <tr>
#               <td class="html7magic">
#                <label for="email">
#                 Adres e-mail lub numer telefonu
#                </label>
#               </td>
#               <td class="html7magic">
#                <label for="pass">
#                 Hasło
#                </label>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <input class="inputtext" id="email" name="email" tabindex="1" type="email" value=""/>
#               </td>
#               <td>
#                <input class="inputtext" id="pass" name="pass" tabindex="2" type="password"/>
#               </td>
#               <td>
#                <label class="uiButton uiButtonConfirm" for="u_0_0" id="loginbutton">
#                 <input id="u_0_0" tabindex="4" type="submit" value="Zaloguj się"/>
#                </label>
#               </td>
#              </tr>
#              <tr>
#               <td class="login_form_label_field">
#                <div>
#                 <div class="uiInputLabel clearfix uiInputLabelLegacy">
#                  <input class="uiInputLabelInput uiInputLabelCheckbox" id="persist_box" name="persistent" tabindex="3" type="checkbox" value="1"/>
#                  <label class="uiInputLabelLabel" for="persist_box">
#                   Nie wylogowuj mnie
#                  </label>
#                 </div>
#                 <input name="default_persistent" type="hidden" value="0"/>
#                </div>
#               </td>
#               <td class="login_form_label_field">
#                <a href="/recover/initiate?lwv=110">
#                 Nie pamiętasz hasła?
#                </a>
#               </td>
#              </tr>
#             </table>
#             <input autocomplete="off" id="u_0_1" name="timezone" type="hidden" value=""/>
#             <input autocomplete="off" id="u_0_2" name="lgndim" type="hidden" value=""/>
#             <input name="lgnrnd" type="hidden" value="164313_ELoF"/>
#             <input id="lgnjs" name="lgnjs" type="hidden" value="n"/>
#             <input autocomplete="off" id="locale" name="locale" type="hidden" value="pl_PL"/>
#             <input autocomplete="off" name="next" type="hidden" value="https://www.facebook.com/psorek139"/>
#            </form>
#           </div>
#          </div>
#         </div>
#         <div class="signupBanner">
#          <div class="signup_bar_container">
#           <div class="signup_box clearfix">
#            <span class="signup_box_content">
#             <a class="_42ft _4jy0 signup_btn _4jy4 _4jy2 selected _51sy" href="/r.php?locale=pl_PL" role="button">
#              Rejestracja
#             </a>
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="uiContextualLayerParent" id="globalContainer">
#     <div class="fb_content clearfix " id="content" role="main">
#      <div class="mvl ptm uiInterstitial uiInterstitialLarge uiBoxWhite">
#       <div class="uiHeader uiHeaderWithImage uiHeaderBottomBorder mhl mts uiHeaderPage interstitialHeader">
#        <div class="clearfix uiHeaderTop">
#         <div class="rfloat _ohf">
#          <h2 class="accessible_elem">
#           Niestety, ta treść jest obecnie niedostępna
#          </h2>
#          <div class="uiHeaderActions">
#          </div>
#         </div>
#         <div>
#          <h2 aria-hidden="true" class="uiHeaderTitle">
#           <i class="uiHeaderImage img sp_WDdjeLdfvHt sx_e38c51">
#           </i>
#           Niestety, ta treść jest obecnie niedostępna
#          </h2>
#         </div>
#        </div>
#       </div>
#       <div class="phl ptm uiInterstitialContent">
#        <div>
#         Być może użyty link wygasł lub strona jest widoczna tylko dla grupy odbiorców, do której nie należysz.
#        </div>
#        <div class="mtm fsm fwn fcg">
#         <a data-gt='{"target":"back","marketing_page_click":"1","conversion":"1"}' href="#" onclick="history.back();" role="button">
#          Wróć do poprzedniej strony
#         </a>
#         <span aria-hidden="true" role="presentation">
#          ·
#         </span>
#         <a data-gt='{"target":"home","marketing_page_click":"1","conversion":"1"}' href="https://www.facebook.com/">
#          Przejdź do aktualności
#         </a>
#         <span aria-hidden="true" role="presentation">
#          ·
#         </span>
#         <a data-gt='{"target":"help","marketing_page_click":"1","conversion":"1"}' href="/help/?ref=404">
#          Odwiedź nasze Centrum pomocy
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div data-referrer="page_footer" id="pageFooter">
#      <div id="contentCurve">
#      </div>
#      <div aria-label="Odnośniki do stron Facebooka" role="contentinfo">
#       <table cellpadding="0" cellspacing="0" class="uiGrid _51mz navigationGrid">
#        <tbody>
#         <tr class="_51mx">
#          <td class="_51m- hLeft plm">
#           <a href="/r.php" title="Zarejestruj się na Facebooku">
#            Rejestracja
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/login/" title="Zaloguj się do Facebooka">
#            Zaloguj się
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="https://messenger.com/" title="Wypróbuj aplikację Messenger.">
#            Messenger
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/lite/" title="Facebook Lite dla systemu Android">
#            Facebook Lite
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/mobile/?ref=pf" title="Wypróbuj Facebook Mobile">
#            Facebook Mobile
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/find-friends?ref=pf" title="Znajdź ludzi w sieci.">
#            Szukaj znajomych
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/badges/?ref=pf" title="Wstaw wizytówkę Facebooka na swojej stronie.">
#            Wizytówki
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/directory/people/" title="Przeglądaj nasz katalog osób.">
#            Osoby
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/directory/pages/" title="Przeglądaj nasz katalog stron.">
#            Strony
#           </a>
#          </td>
#          <td class="_51m- hLeft plm _51mw">
#           <a href="/places/" title="Sprawdź najpopularniejsze miejsca na Facebooku.">
#            Miejsca
#           </a>
#          </td>
#         </tr>
#         <tr class="_51mx">
#          <td class="_51m- hLeft plm">
#           <a href="/games/" title="Wypróbuj gry na Facebooku">
#            Gry
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/directory/places/" title="Przejrzyj nasz katalog miejsc.">
#            Lokalizacje
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a accesskey="8" href="/facebook" title="Przeczytaj nasz blog, odkryj centrum zasobów i znajdź pracę.">
#            O Facebooku
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/campaign/landing.php?placement=pflo&amp;campaign_id=402047449186&amp;extra_1=auto" title="Reklama na Facebooku">
#            Utwórz reklamę
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/pages/create/?ref_type=sitefooter" title="Utwórz stronę">
#            Utwórz stronę
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="https://developers.facebook.com/?ref=pf" title="Twórz na naszej platformie.">
#            Twórcy aplikacji
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/careers/?ref=pf" title="Buduj swoją karierę w naszej wspaniałej firmie.">
#            Praca
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/privacy/explanation" title="Dowiedz się o swojej prywatności na Facebooku.">
#            Prywatność
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a href="/help/cookies/?ref=sitefooter" title="Dowiedz się więcej na temat plików cookies i Facebooka.">
#            Pliki cookie
#           </a>
#          </td>
#          <td class="_51m- hLeft plm _51mw">
#           <a class="_41ug" href="https://www.facebook.com/help/568137493302217" title="Dowiedz się więcej o opcjach wyświetlania reklamy.">
#            Opcje wyświetlania reklam
#            <i class="img sp_trmaA_gws9n sx_ade52c">
#            </i>
#           </a>
#          </td>
#         </tr>
#         <tr class="_51mx">
#          <td class="_51m- hLeft plm">
#           <a accesskey="9" href="/policies/?ref=pf" title="Zapoznaj się z naszym regulaminem i zasadami.">
#            Regulamin
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a accesskey="0" href="/help/?ref=pf" title="Odwiedź nasze Centrum pomocy.">
#            Pomoc
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a accesskey="6" class="accessible_elem" href="/settings" title="Wyświetl i edytuj ustawienia Facebooka.">
#            Ustawienia
#           </a>
#          </td>
#          <td class="_51m- hLeft plm">
#           <a accesskey="7" class="accessible_elem" href="/allactivity?privacy_source=activity_log_top_menu" title="Zobacz dziennik aktywności">
#            Dziennik aktywności
#           </a>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#      <div class="mvl copyright">
#       <div>
#        <span>
#         Facebook © 2015
#        </span>
#        <div class="fsm fwn fcg">
#         <a ajaxify="/settings/language/language/?uri=https%3A%2F%2Fwww.facebook.com%2Fpsorek139&amp;source=TOP_LOCALES_DIALOG" href="#" rel="dialog" role="button" title="Korzystaj z Facebooka w innym języku.">
#          Polski
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    requireLazy(["Bootloader"], function(Bootloader) {Bootloader.setResourceMap({"nWXdP":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yt\/r\/L3RovIVf3Tl.js","crossOrigin":1},"Fy7Lj":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yP\/r\/Ejmu2eNiQ3q.js","crossOrigin":1},"US6To":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/y9\/r\/Gkem9180kcO.js","crossOrigin":1},"4vv8\/":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yO\/r\/hiWQlvAyz5m.js","crossOrigin":1},"PLwFo":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yy\/r\/i03-myZWZCs.js","crossOrigin":1},"pzne\/":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yt\/r\/NTr53PqrL8s.js","crossOrigin":1},"Yqijp":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yY\/r\/Se5yd4F4bHX.js","crossOrigin":1},"d7V4X":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yS\/r\/ZDQXrINXZRK.js","crossOrigin":1},"ZcZ7W":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yz\/r\/UVke_oQtM7M.js","crossOrigin":1},"JFm3U":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yu\/r\/CB1sIH0jB-M.js","crossOrigin":1},"ccpBO":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yK\/r\/UPWqolLfcie.js","crossOrigin":1},"+ClWy":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yF\/r\/A0qdgknEnD5.js","crossOrigin":1},"oivac":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yi\/r\/5Zkzgyj1L5V.js","crossOrigin":1},"Jzhfd":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yL\/r\/UIKqnWvum5p.js","crossOrigin":1},"qIrGg":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yW\/r\/K4XNCHcdiBU.js","crossOrigin":1},"WRjxQ":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/ye\/r\/Nczzy6Ho1or.js","crossOrigin":1},"L1k\/a":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yT\/r\/pLR_pv_fs_j.js","crossOrigin":1},"oE4Do":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/ye\/r\/K9O3qPDtfqb.js","crossOrigin":1},"1ys2A":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yg\/r\/r5KKIFPSU6f.js","crossOrigin":1},"cNca2":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yS\/r\/_uW33I9lkJl.js","crossOrigin":1},"ROOwM":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yT\/r\/-6dhns2ZZLs.js","crossOrigin":1},"EfJl2":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yJ\/r\/g1gq-Eb3QWf.js","crossOrigin":1},"aMmtm":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yu\/r\/MpkSDWxVDvi.js","crossOrigin":1},"4VhGA":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yR\/r\/PGtIdVvTRmT.js","crossOrigin":1},"yxLBJ":{"type":"css","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yk\/r\/5qLwML2FYam.css","permanent":1,"crossOrigin":1},"2WeDo":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yh\/r\/kxU0odpifA3.js","crossOrigin":1},"HV8NH":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yC\/r\/9nFitAk55O6.js","crossOrigin":1},"M+8Pv":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yU\/r\/SsrND_9xPNW.js","crossOrigin":1},"VDymv":{"type":"css","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yP\/r\/_917XGvlm0n.css","permanent":1,"crossOrigin":1},"Rs18G":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yY\/r\/z9xrgSKFbeZ.js","crossOrigin":1},"6AU0l":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yO\/r\/XbyDDqm4ZNH.js","crossOrigin":1},"AtxWD":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yu\/r\/mOwquNMdiEH.js","crossOrigin":1},"NxpxU":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yX\/r\/lcH8v6oEgpJ.js","crossOrigin":1},"zyFOp":{"type":"js","src":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/yz\/r\/ivYdZ9oXqgz.js","crossOrigin":1},"Fcie9":{"type":"css","src":"https:\/\/stat ...
# requireLazy(["ix"], function(ix) {ix.add({"arrow-right:white:small":{"sprited":true,"spriteMapCssClass":"sp_fD1OukDg271","spriteCssClass":"sx_6d7ac6"}});});
#   </script>
#   <script>
#    requireLazy(["InitialJSLoader"], function(InitialJSLoader) {InitialJSLoader.loadOnDOMContentReady(["nWXdP","Fy7Lj","US6To","4vv8\/","PLwFo","pzne\/","Yqijp"]);});
#   </script>
#   <script>
#    require("TimeSlice").guard(function() {require("ServerJSDefine").handleDefines([]);require("InitialJSLoader").handleServerJS({"elements":[["__elem_835c633a_0_0","login_form",1],["__elem_1edd4980_0_0","loginbutton",1],["__elem_f46f4946_0_0","u_0_1",1],["__elem_f46f4946_0_1","u_0_2",1],["__elem_85b7cbf7_0_0","login_form",1],["__elem_a588f507_0_0","globalContainer",1]],"require":[["Cookie","setIfFirstPartyContext",[],["_js_datr","ofc7VmbKTjf8RFDepRFnd6jl",63072000000,"\/",false],[]],["PostLoadJS","loadAndRequire",[],["DimensionTracking"],[]],["PostLoadJS","loadAndCall",[],["HighContrastMode","init",[{"isHCM":false,"spacerImage":"https:\/\/static.xx.fbcdn.net\/rsrc.php\/v2\/y4\/r\/-PAXP-deijE.gif"}]],[]],["PostLoadJS","loadAndCall",[],["DetectBrokenProxyCache","run",[0,"c_user"]],[]],["ClickRefLogger"],["ScriptPath","set",[],["WebProfilePreflightController","dc7d82c6",{"imp_id":"45a91dbc","entity_id":"100000911065402"}],[]],["KappaWrapper","start",[],[6,5,10],[]],["UserActionHistory"],["ScriptPathLogger","startLogging",[],[],[]],["TimeSpentBitArrayLogger","init",[],[],[]],["NavigationClickPointHandler"],["UITinyViewportAction","init",[],[],[]],["ResetScrollOnUnload","init",["__elem_a588f507_0_0"],[{"__m":"__elem_a588f507_0_0"}],[]],["WebStorageMonster","schedule",[],[false],[]],["AsyncRequestNectarLogging"],["TimezoneAutoset","setInputValue",["__elem_f46f4946_0_0"],[{"__m":"__elem_f46f4946_0_0"},1446770593],[]],["ScreenDimensionsAutoSet","setInputValue",["__elem_f46f4946_0_1"],[{"__m":"__elem_f46f4946_0_1"}],[]],["LoginFormController","init",["__elem_835c633a_0_0","__elem_1edd4980_0_0"],[{"__m":"__elem_835c633a_0_0"},{"__m":"__elem_1edd4980_0_0"},null],[]],["PostLoadJS","loadAndCall",[],["QuickSandSolver","solveAndUpdateForm",[1,"?~?.???)??h?2e ?L\u001f???\u0006\u4201\btW",10,42,100,"login_form","AZl7oWlSWvuJer-_zma32lW2sI8-7TFMuAw05DZCgO2Lmr77we3GDnfC09DYNx_MCLWwSSRt1XMrpD4caXMN9GrNRGaD7zWjZ5l6GmjB75G8Gfd0rAtrQcyLYRrDUuWGHwAc3tAdUni_ji6SgXQOAR8_KrcwA9EP8kgMWywjKab-9JmUIvd47duCmp5-QPZcUwpmjoFqbtB6O82up6aRADni"]],[]],["FocusListener"],["FlipDirectionOnKeypress"],["TimeSlice","setLogging",[],[0,0.01],[]],["NavigationMetrics","setPage",[],[{"page":"WebProfilePreflightController","page_type":"normal","page_uri":"https:\/\/www.facebook.com\/psorek139"}],[]]]});}, "ServerJS define", {"root":true})();
#
# onloadRegister_DEPRECATED(function (){try { $("email").focus(); } catch (_ignore) { }});
#   </script>
#   <!-- BigPipe construction and first response -->
#   <script>
#    var bigPipe = new (require("BigPipe"))({"lid":"6213832383058488249","forceFinish":true});
#   </script>
#   <script>
#    bigPipe.beforePageletArrive("first_response")
#   </script>
#   <script>
#    require("TimeSlice").guard(function() {bigPipe.onPageletArrive({"id":"first_response","phase":0,"jsmods":{},"is_last":true,"allResources":["Ltgte","8Pnum","2smJx","zIx9O","nWXdP","Fy7Lj","US6To","4vv8\/","0Qu7U","PLwFo","pzne\/","Yqijp"],"displayResources":["Ltgte","8Pnum","2smJx","zIx9O","0Qu7U"]});}, "onPageletArrive first_response", {"root":true,"pagelet":"first_response"})();
#   </script>
#   <script>
#    bigPipe.beforePageletArrive("last_response")
#   </script>
#   <script>
#    require("TimeSlice").guard(function() {bigPipe.onPageletArrive({"id":"last_response","phase":1,"jsmods":{"define":[["TimeSpentConfig",[],{"0_delay":0,"0_timeout":8,"delay":200000,"timeout":64},142],["ImmediateActiveSecondsConfig",[],{"sampling_rate":0},423]]},"is_last":true,"allResources":["Ltgte","8Pnum","2smJx","zIx9O","nWXdP","Fy7Lj","US6To","4vv8\/","0Qu7U","PLwFo","pzne\/","Yqijp"],"displayResources":["Ltgte","8Pnum","2smJx","zIx9O","0Qu7U"],"the_end":true});}, "onPageletArrive last_response", {"root":true,"pagelet":"last_response"})();
#   </script>
#  </body>
# </html>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-113-719725fad943> in <module>()
#       2 url="https://www.facebook.com/psorek139"
#       3 page=urllib2.urlopen(url)
# ----> 4 print(getFriends(page))
#       5
#
# <ipython-input-112-604dbea04850> in getFriends(link)
#       3     wojtek = BeautifulSoup(link.read())
#       4     print(wojtek.prettify())
# ----> 5     friends = wojtek.findAll('a', {'class' :'uiLinkSubtle'}, href=re.compile('friends$'))[0].string
#       6     name = wojtek.findAll('span', {'id' :'fb-timeline-cover-name'})[0].string.split(' ', 1)[0]
#       7     print(name + " " + friends)
#
# IndexError: list index out of range
